# %% [markdown]
# # 1. Setup Environment & Configuration

# %%
import os
import torch

# Verify GPU availability
print(f"CUDA Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Device: {torch.cuda.get_device_name(0)}")

# Define project paths (Adjust these relative to your notebook location)
# Assuming notebook is in the root or a subfolder, we set absolute paths for safety.
PROJECT_ROOT = os.path.abspath(".")
WORKSPACE = os.path.join(PROJECT_ROOT, "workspace")
DATA_DIR = os.path.join(WORKSPACE, "data")
LOGS_DIR = os.path.join(WORKSPACE, "logs")
CONFIGS_DIR = os.path.join(
    PROJECT_ROOT, "config"
)  

os.makedirs(DATA_DIR, exist_ok=True)
os.makedirs(LOGS_DIR, exist_ok=True)

# Create .env file required by src/utils/path_utils.py
env_content = f"""
SOURCE_DATA_DIR={DATA_DIR}
LOGS_DIR={LOGS_DIR}
CONFIGS_DIR={CONFIGS_DIR}
MODELS_DIR={os.path.join(LOGS_DIR, "models")}
STORAGE_DIR={os.path.join(LOGS_DIR, "storage")}
"""

with open(".env", "w") as f:
    f.write(env_content)

print("Created .env file with the following configuration:")
print(env_content)
# Out:
# CUDA Available: True
# Device: NVIDIA GeForce RTX 3070 Ti Laptop GPU
# Created .env file with the following configuration:
#
# SOURCE_DATA_DIR=/home/prg/GitHub/semi-supervised-gnn-drug-discovery/workspace/data
# LOGS_DIR=/home/prg/GitHub/semi-supervised-gnn-drug-discovery/workspace/logs
# CONFIGS_DIR=/home/prg/GitHub/semi-supervised-gnn-drug-discovery/config
# MODELS_DIR=/home/prg/GitHub/semi-supervised-gnn-drug-discovery/workspace/logs/models
# STORAGE_DIR=/home/prg/GitHub/semi-supervised-gnn-drug-discovery/workspace/logs/storage

# %% [markdown]
# ## Experiment Runner Helper

# %%
import subprocess
import sys
import os


def run_experiment(module_path, overrides):
    """
    Runs a training script as a module with Hydra overrides.

    Args:
        module_path (str): Python module path (e.g. 'src.trainers.baseline_trainer')
        overrides (list): List of Hydra override strings
    """

    module_path = module_path.strip()

    cmd = [sys.executable, "-m", module_path] + overrides

    print(f"Running: {' '.join(cmd)}\n" + "=" * 50)

    cwd = os.getcwd()

    process = subprocess.Popen(
        cmd,
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE,
        text=True,
        bufsize=1,
        universal_newlines=True,
        cwd=cwd,
    )

    # Print output in real-time
    with process.stdout:
        for line in iter(process.stdout.readline, ""):
            print(line, end="")

    return_code = process.wait()

    if return_code != 0:
        print(f"\nError running experiment. Return code: {return_code}")

        print(process.stderr.read())
    else:
        print("\nExperiment completed successfully.")


BASELINE_TRAINER = "src.trainers.baseline_trainer"
MEAN_TEACHER_TRAINER = "src.trainers.mean_teacher_trainer"

# %% [markdown]
# ## Experiments

# %% [markdown]
# - Experiment 1: [0.35,0.35,0.1,0.2]"
# - Experiment 2: [0.56,0.14,0.1,0.2]"
# - Experiment 3: [0.63,0.07,0.1,0.2]"
# - Experiment 4: [0.67,0.03,0.1,0.2]"

# %%
split = "[0.67,0.03,0.1,0.2]"
mode = "supervised"
dataset =

# %% [markdown]
# ### Supervised Baseline

# %%
# Common splits for semi-supervised learning [Unlabeled, Labeled, Val, Test]

# - Experiment 1: [0.35,0.35,0.1,0.2]"
# - Experiment 2: [0.56,0.14,0.1,0.2]"
# - Experiment 3: [0.63,0.07,0.1,0.2]"
# - Experiment 4: [0.67,0.03,0.1,0.2]"

SSL_SPLITS = "[0.67,0.03,0.1,0.2]"

# ---Supervised Baseline---
sider_baseline_overrides = [
    "dataset=moleculenet",
    "dataset.init.name=SIDER", # SIDER, TOX21 or PCBA
    f"dataset.init.splits={SSL_SPLITS}",
    "dataset.init.batch_size_train=32",
    "dataset.init.mu=1",
    "trainer.init.max_epochs=100",  # Reduced for demo purposes
    "logger.wandb.project=SIDER_Experiments",
]
run_experiment(BASELINE_TRAINER, sider_baseline_overrides)
# Out:
# Running: /home/prg/miniconda3/envs/monai_env/bin/python -m src.trainers.baseline_trainer dataset=moleculenet dataset.init.name=sider dataset.init.splits=[0.67,0.03,0.1,0.2] model=ginev2 trainer.init.max_epochs=100 logger.wandb.project=SIDER_Experiments
# ==================================================
# dataset:
#   name: moleculenet
#   init:
#     _target_: src.data.moleculenet.MoleculeNetDataModule
#     target: null
#     batch_size_train: 256
#     batch_size_inference: 64
#     num_workers: 4
#     splits:
#     - 0.67
#     - 0.03
#     - 0.1
#     - 0.2
#     seed: 42
#     mu: 22
#     subset_size: null
#     data_augmentation: false
#     mode: supervised
#     name: sider
# model:
#   name: GINEv2
#   init:
#     _target_: src.models.nets.gine_v2.GINEv2
#     _recursive_: false
#     embedding_dim: 16
#     hidden_channels: 256
#     encoder_num_heads: 4
#     encoder_dropout: 0.1
#     num_gnn_layers: 4
#     gnn_mlp_layers: 2
#     readout_mlp_layers: 2
#     dropout: 0.5
#     activation: relu
#     pooling_type: mean
#     use_residual: true
#     learn_eps: true
# lightning_module:
#   init:
#     _target_: src.lightning_modules.baseline.BaselineModule
#     learning_rate: 0.0005
#     optimizer: adamw
#     warmup_epochs: 75
#     cosine_period_ratio: 0.5
#     compile: false
#     weights: null
#     weight_decay: 0.001
#     nesterov: true
#     momentum: 0.9
# trainer:
#   init:
#     _target_: pytorch_lightning.Trainer
#     max_epochs: 100
#     accelerator: auto
#     devices: 1
#     precision: bf16-mixed
#     accumulate_grad_batches: 1
#     log_every_n_steps: 35
#     check_val_every_n_epoch: 1
#     enable_checkpointing: true
#     enable_progress_bar: true
#     enable_model_summary: true
#     deterministic: false
#     benchmark: false
#     callbacks:
#     - _target_: pytorch_lightning.callbacks.ModelCheckpoint
#       monitor: val/ap
#       mode: max
#       save_top_k: 1
#       save_last: false
#       filename: best
#       auto_insert_metric_name: false
#     - _target_: pytorch_lightning.callbacks.ModelCheckpoint
#       save_top_k: 0
#       save_last: true
#       filename: last
#       verbose: false
#     - _target_: pytorch_lightning.callbacks.LearningRateMonitor
#       logging_interval: epoch
# logger:
#   wandb:
#     _target_: pytorch_lightning.loggers.WandbLogger
#     name: ${dataset.name}_${model.name}_${now:%Y-%m-%d_%H-%M-%S}
#     project: SIDER_Experiments
#     save_dir: ${oc.env:LOGS_DIR}
#     offline: false
#     log_model: false
#     tags:
#     - ${dataset.name}
#     - ${model.name}
#     notes: Experiment with ${dataset.name} dataset
# seed: 42
# force_deterministic: true
#
# Using supervised mode.
# Moleculenet sider dataset loaded with 42 labeled, 142 validation, and 287 test samples.
# Batch sizes: labeled=256
# Num node features: 9
# Num edge features: 3
# Dataset properties:
# Task type: classification
# Number of node features: 9
# Number of edge features: 3
# Number of tasks: 27
# Model properties:
# Model name: GINEv2
# Using supervised mode.
# Moleculenet sider dataset loaded with 42 labeled, 142 validation, and 287 test samples.
# Batch sizes: labeled=256
#
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Sanity Checking:   0%|          | 0/2 [00:00<?, ?it/s]
# Sanity Checking DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Sanity Checking DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.91it/s]
# Sanity Checking DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  9.37it/s]
#
#
# Training: |          | 0/? [00:00<?, ?it/s]
# Training:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0: 100%|██████████| 1/1 [00:00<00:00,  9.73it/s]
# Epoch 0: 100%|██████████| 1/1 [00:00<00:00,  9.66it/s, v_num=pdp2]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 153.14it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 190.87it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 211.24it/s]
#
#
# Epoch 0: 100%|██████████| 1/1 [00:00<00:00,  5.95it/s, v_num=pdp2, val/loss=0.603]
# Epoch 0: 100%|██████████| 1/1 [00:00<00:00,  5.91it/s, v_num=pdp2, val/loss=0.603]
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.603]
# Epoch 1:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.603]
# Epoch 1: 100%|██████████| 1/1 [00:00<00:00, 38.51it/s, v_num=pdp2, val/loss=0.603]
# Epoch 1: 100%|██████████| 1/1 [00:00<00:00, 37.74it/s, v_num=pdp2, val/loss=0.603]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 194.28it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 220.12it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 232.47it/s]
#
#
# Epoch 1: 100%|██████████| 1/1 [00:00<00:00, 10.80it/s, v_num=pdp2, val/loss=0.603]
# Epoch 1: 100%|██████████| 1/1 [00:00<00:00, 10.68it/s, v_num=pdp2, val/loss=0.603]
# Epoch 1:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.603]
# Epoch 2:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.603]
# Epoch 2: 100%|██████████| 1/1 [00:00<00:00, 52.29it/s, v_num=pdp2, val/loss=0.603]
# Epoch 2: 100%|██████████| 1/1 [00:00<00:00, 51.05it/s, v_num=pdp2, val/loss=0.603]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 184.53it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 218.57it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 240.42it/s]
#
#
# Epoch 2: 100%|██████████| 1/1 [00:00<00:00, 12.01it/s, v_num=pdp2, val/loss=0.603]
# Epoch 2: 100%|██████████| 1/1 [00:00<00:00, 11.89it/s, v_num=pdp2, val/loss=0.603]
# Epoch 2:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.603]
# Epoch 3:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.603]
# Epoch 3: 100%|██████████| 1/1 [00:00<00:00, 62.05it/s, v_num=pdp2, val/loss=0.603]
# Epoch 3: 100%|██████████| 1/1 [00:00<00:00, 60.56it/s, v_num=pdp2, val/loss=0.603]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 185.42it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 214.48it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 223.20it/s]
#
#
# Epoch 3: 100%|██████████| 1/1 [00:00<00:00, 12.95it/s, v_num=pdp2, val/loss=0.604]
# Epoch 3: 100%|██████████| 1/1 [00:00<00:00, 12.81it/s, v_num=pdp2, val/loss=0.604]
# Epoch 3:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.604]
# Epoch 4:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.604]
# Epoch 4: 100%|██████████| 1/1 [00:00<00:00, 65.54it/s, v_num=pdp2, val/loss=0.604]
# Epoch 4: 100%|██████████| 1/1 [00:00<00:00, 63.70it/s, v_num=pdp2, val/loss=0.604]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 182.14it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 204.87it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 223.29it/s]
#
#
# Epoch 4: 100%|██████████| 1/1 [00:00<00:00, 12.73it/s, v_num=pdp2, val/loss=0.606]
# Epoch 4: 100%|██████████| 1/1 [00:00<00:00, 12.51it/s, v_num=pdp2, val/loss=0.606]
# Epoch 4:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.606]
# Epoch 5:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.606]
# Epoch 5: 100%|██████████| 1/1 [00:00<00:00, 60.83it/s, v_num=pdp2, val/loss=0.606]
# Epoch 5: 100%|██████████| 1/1 [00:00<00:00, 59.48it/s, v_num=pdp2, val/loss=0.606]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 212.84it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 234.66it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 249.10it/s]
#
#
# Epoch 5: 100%|██████████| 1/1 [00:00<00:00, 11.21it/s, v_num=pdp2, val/loss=0.607]
# Epoch 5: 100%|██████████| 1/1 [00:00<00:00, 11.11it/s, v_num=pdp2, val/loss=0.607]
# Epoch 5:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.607]
# Epoch 6:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.607]
# Epoch 6: 100%|██████████| 1/1 [00:00<00:00, 68.47it/s, v_num=pdp2, val/loss=0.607]
# Epoch 6: 100%|██████████| 1/1 [00:00<00:00, 66.68it/s, v_num=pdp2, val/loss=0.607]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 102.84it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 126.42it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 156.34it/s]
#
#
# Epoch 6: 100%|██████████| 1/1 [00:00<00:00, 11.88it/s, v_num=pdp2, val/loss=0.608]
# Epoch 6: 100%|██████████| 1/1 [00:00<00:00, 11.77it/s, v_num=pdp2, val/loss=0.608]
# Epoch 6:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.608]
# Epoch 7:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.608]
# Epoch 7: 100%|██████████| 1/1 [00:00<00:00, 46.42it/s, v_num=pdp2, val/loss=0.608]
# Epoch 7: 100%|██████████| 1/1 [00:00<00:00, 45.45it/s, v_num=pdp2, val/loss=0.608]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 110.12it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 157.02it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 185.96it/s]
#
#
# Epoch 7: 100%|██████████| 1/1 [00:00<00:00, 11.61it/s, v_num=pdp2, val/loss=0.609]
# Epoch 7: 100%|██████████| 1/1 [00:00<00:00, 11.50it/s, v_num=pdp2, val/loss=0.609]
# Epoch 7:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.609]
# Epoch 8:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.609]
# Epoch 8: 100%|██████████| 1/1 [00:00<00:00, 52.35it/s, v_num=pdp2, val/loss=0.609]
# Epoch 8: 100%|██████████| 1/1 [00:00<00:00, 51.03it/s, v_num=pdp2, val/loss=0.609]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 199.68it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 189.53it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 211.98it/s]
#
#
# Epoch 8: 100%|██████████| 1/1 [00:00<00:00, 11.53it/s, v_num=pdp2, val/loss=0.611]
# Epoch 8: 100%|██████████| 1/1 [00:00<00:00, 11.42it/s, v_num=pdp2, val/loss=0.611]
# Epoch 8:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.611]
# Epoch 9:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.611]
# Epoch 9: 100%|██████████| 1/1 [00:00<00:00, 47.34it/s, v_num=pdp2, val/loss=0.611]
# Epoch 9: 100%|██████████| 1/1 [00:00<00:00, 46.31it/s, v_num=pdp2, val/loss=0.611]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 150.03it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 162.20it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 185.34it/s]
#
#
# Epoch 9: 100%|██████████| 1/1 [00:00<00:00, 11.31it/s, v_num=pdp2, val/loss=0.612]
# Epoch 9: 100%|██████████| 1/1 [00:00<00:00, 11.19it/s, v_num=pdp2, val/loss=0.612]
# Epoch 9:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.612]
# Epoch 10:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.612]
# Epoch 10: 100%|██████████| 1/1 [00:00<00:00, 61.02it/s, v_num=pdp2, val/loss=0.612]
# Epoch 10: 100%|██████████| 1/1 [00:00<00:00, 59.23it/s, v_num=pdp2, val/loss=0.612]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 171.06it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 210.84it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 233.49it/s]
#
#
# Epoch 10: 100%|██████████| 1/1 [00:00<00:00, 12.96it/s, v_num=pdp2, val/loss=0.613]
# Epoch 10: 100%|██████████| 1/1 [00:00<00:00, 12.83it/s, v_num=pdp2, val/loss=0.613]
# Epoch 10:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.613]
# Epoch 11:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.613]
# Epoch 11: 100%|██████████| 1/1 [00:00<00:00, 47.70it/s, v_num=pdp2, val/loss=0.613]
# Epoch 11: 100%|██████████| 1/1 [00:00<00:00, 46.81it/s, v_num=pdp2, val/loss=0.613]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 199.79it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 218.96it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 231.32it/s]
#
#
# Epoch 11: 100%|██████████| 1/1 [00:00<00:00, 12.23it/s, v_num=pdp2, val/loss=0.614]
# Epoch 11: 100%|██████████| 1/1 [00:00<00:00, 12.12it/s, v_num=pdp2, val/loss=0.614]
# Epoch 11:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.614]
# Epoch 12:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.614]
# Epoch 12: 100%|██████████| 1/1 [00:00<00:00, 60.02it/s, v_num=pdp2, val/loss=0.614]
# Epoch 12: 100%|██████████| 1/1 [00:00<00:00, 58.49it/s, v_num=pdp2, val/loss=0.614]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 179.86it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 215.58it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 238.26it/s]
#
#
# Epoch 12: 100%|██████████| 1/1 [00:00<00:00, 13.25it/s, v_num=pdp2, val/loss=0.615]
# Epoch 12: 100%|██████████| 1/1 [00:00<00:00, 13.00it/s, v_num=pdp2, val/loss=0.615]
# Epoch 12:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.615]
# Epoch 13:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.615]
# Epoch 13: 100%|██████████| 1/1 [00:00<00:00, 59.49it/s, v_num=pdp2, val/loss=0.615]
# Epoch 13: 100%|██████████| 1/1 [00:00<00:00, 58.28it/s, v_num=pdp2, val/loss=0.615]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 179.27it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 217.21it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 237.78it/s]
#
#
# Epoch 13: 100%|██████████| 1/1 [00:00<00:00, 12.70it/s, v_num=pdp2, val/loss=0.616]
# Epoch 13: 100%|██████████| 1/1 [00:00<00:00, 12.49it/s, v_num=pdp2, val/loss=0.616]
# Epoch 13:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.616]
# Epoch 14:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.616]
# Epoch 14: 100%|██████████| 1/1 [00:00<00:00, 55.51it/s, v_num=pdp2, val/loss=0.616]
# Epoch 14: 100%|██████████| 1/1 [00:00<00:00, 54.01it/s, v_num=pdp2, val/loss=0.616]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 203.96it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 231.61it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 247.24it/s]
#
#
# Epoch 14: 100%|██████████| 1/1 [00:00<00:00, 13.12it/s, v_num=pdp2, val/loss=0.616]
# Epoch 14: 100%|██████████| 1/1 [00:00<00:00, 12.98it/s, v_num=pdp2, val/loss=0.616]
# Epoch 14:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.616]
# Epoch 15:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.616]
# Epoch 15: 100%|██████████| 1/1 [00:00<00:00, 52.91it/s, v_num=pdp2, val/loss=0.616]
# Epoch 15: 100%|██████████| 1/1 [00:00<00:00, 51.56it/s, v_num=pdp2, val/loss=0.616]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 208.41it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 234.03it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 250.49it/s]
#
#
# Epoch 15: 100%|██████████| 1/1 [00:00<00:00, 12.12it/s, v_num=pdp2, val/loss=0.616]
# Epoch 15: 100%|██████████| 1/1 [00:00<00:00, 11.99it/s, v_num=pdp2, val/loss=0.616]
# Epoch 15:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.616]
# Epoch 16:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.616]
# Epoch 16: 100%|██████████| 1/1 [00:00<00:00, 63.19it/s, v_num=pdp2, val/loss=0.616]
# Epoch 16: 100%|██████████| 1/1 [00:00<00:00, 61.61it/s, v_num=pdp2, val/loss=0.616]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 138.20it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 178.78it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 203.26it/s]
#
#
# Epoch 16: 100%|██████████| 1/1 [00:00<00:00, 12.95it/s, v_num=pdp2, val/loss=0.617]
# Epoch 16: 100%|██████████| 1/1 [00:00<00:00, 12.82it/s, v_num=pdp2, val/loss=0.617]
# Epoch 16:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.617]
# Epoch 17:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.617]
# Epoch 17: 100%|██████████| 1/1 [00:00<00:00, 46.27it/s, v_num=pdp2, val/loss=0.617]
# Epoch 17: 100%|██████████| 1/1 [00:00<00:00, 45.41it/s, v_num=pdp2, val/loss=0.617]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 194.58it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 227.50it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 250.40it/s]
#
#
# Epoch 17: 100%|██████████| 1/1 [00:00<00:00, 12.57it/s, v_num=pdp2, val/loss=0.617]
# Epoch 17: 100%|██████████| 1/1 [00:00<00:00, 12.45it/s, v_num=pdp2, val/loss=0.617]
# Epoch 17:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.617]
# Epoch 18:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.617]
# Epoch 18: 100%|██████████| 1/1 [00:00<00:00, 54.89it/s, v_num=pdp2, val/loss=0.617]
# Epoch 18: 100%|██████████| 1/1 [00:00<00:00, 53.81it/s, v_num=pdp2, val/loss=0.617]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 113.86it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 156.26it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 182.31it/s]
#
#
# Epoch 18: 100%|██████████| 1/1 [00:00<00:00, 12.16it/s, v_num=pdp2, val/loss=0.617]
# Epoch 18: 100%|██████████| 1/1 [00:00<00:00, 11.96it/s, v_num=pdp2, val/loss=0.617]
# Epoch 18:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.617]
# Epoch 19:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.617]
# Epoch 19: 100%|██████████| 1/1 [00:00<00:00, 54.55it/s, v_num=pdp2, val/loss=0.617]
# Epoch 19: 100%|██████████| 1/1 [00:00<00:00, 53.18it/s, v_num=pdp2, val/loss=0.617]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 197.82it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 228.70it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 244.29it/s]
#
#
# Epoch 19: 100%|██████████| 1/1 [00:00<00:00, 12.45it/s, v_num=pdp2, val/loss=0.617]
# Epoch 19: 100%|██████████| 1/1 [00:00<00:00, 12.32it/s, v_num=pdp2, val/loss=0.617]
# Epoch 19:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.617]
# Epoch 20:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.617]
# Epoch 20: 100%|██████████| 1/1 [00:00<00:00, 54.65it/s, v_num=pdp2, val/loss=0.617]
# Epoch 20: 100%|██████████| 1/1 [00:00<00:00, 53.46it/s, v_num=pdp2, val/loss=0.617]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 124.16it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 169.33it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 193.32it/s]
#
#
# Epoch 20: 100%|██████████| 1/1 [00:00<00:00, 12.17it/s, v_num=pdp2, val/loss=0.617]
# Epoch 20: 100%|██████████| 1/1 [00:00<00:00, 12.05it/s, v_num=pdp2, val/loss=0.617]
# Epoch 20:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.617]
# Epoch 21:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.617]
# Epoch 21: 100%|██████████| 1/1 [00:00<00:00, 56.55it/s, v_num=pdp2, val/loss=0.617]
# Epoch 21: 100%|██████████| 1/1 [00:00<00:00, 55.13it/s, v_num=pdp2, val/loss=0.617]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 89.87it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 129.59it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 159.33it/s]
#
#
# Epoch 21: 100%|██████████| 1/1 [00:00<00:00, 11.95it/s, v_num=pdp2, val/loss=0.616]
# Epoch 21: 100%|██████████| 1/1 [00:00<00:00, 11.84it/s, v_num=pdp2, val/loss=0.616]
# Epoch 21:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.616]
# Epoch 22:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.616]
# Epoch 22: 100%|██████████| 1/1 [00:00<00:00, 52.46it/s, v_num=pdp2, val/loss=0.616]
# Epoch 22: 100%|██████████| 1/1 [00:00<00:00, 51.20it/s, v_num=pdp2, val/loss=0.616]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 155.88it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 191.43it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 214.74it/s]
#
#
# Epoch 22: 100%|██████████| 1/1 [00:00<00:00, 12.91it/s, v_num=pdp2, val/loss=0.616]
# Epoch 22: 100%|██████████| 1/1 [00:00<00:00, 12.76it/s, v_num=pdp2, val/loss=0.616]
# Epoch 22:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.616]
# Epoch 23:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.616]
# Epoch 23: 100%|██████████| 1/1 [00:00<00:00, 52.01it/s, v_num=pdp2, val/loss=0.616]
# Epoch 23: 100%|██████████| 1/1 [00:00<00:00, 50.51it/s, v_num=pdp2, val/loss=0.616]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 169.11it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 207.20it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 220.50it/s]
#
#
# Epoch 23: 100%|██████████| 1/1 [00:00<00:00, 12.26it/s, v_num=pdp2, val/loss=0.615]
# Epoch 23: 100%|██████████| 1/1 [00:00<00:00, 12.12it/s, v_num=pdp2, val/loss=0.615]
# Epoch 23:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.615]
# Epoch 24:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.615]
# Epoch 24: 100%|██████████| 1/1 [00:00<00:00, 53.68it/s, v_num=pdp2, val/loss=0.615]
# Epoch 24: 100%|██████████| 1/1 [00:00<00:00, 52.40it/s, v_num=pdp2, val/loss=0.615]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 106.42it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 139.31it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 167.96it/s]
#
#
# Epoch 24: 100%|██████████| 1/1 [00:00<00:00, 12.17it/s, v_num=pdp2, val/loss=0.615]
# Epoch 24: 100%|██████████| 1/1 [00:00<00:00, 11.99it/s, v_num=pdp2, val/loss=0.615]
# Epoch 24:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.615]
# Epoch 25:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.615]
# Epoch 25: 100%|██████████| 1/1 [00:00<00:00, 50.51it/s, v_num=pdp2, val/loss=0.615]
# Epoch 25: 100%|██████████| 1/1 [00:00<00:00, 49.31it/s, v_num=pdp2, val/loss=0.615]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 233.02it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 189.32it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 201.25it/s]
#
#
# Epoch 25: 100%|██████████| 1/1 [00:00<00:00, 12.41it/s, v_num=pdp2, val/loss=0.614]
# Epoch 25: 100%|██████████| 1/1 [00:00<00:00, 12.28it/s, v_num=pdp2, val/loss=0.614]
# Epoch 25:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.614]
# Epoch 26:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.614]
# Epoch 26: 100%|██████████| 1/1 [00:00<00:00, 54.09it/s, v_num=pdp2, val/loss=0.614]
# Epoch 26: 100%|██████████| 1/1 [00:00<00:00, 52.41it/s, v_num=pdp2, val/loss=0.614]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 218.81it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 215.83it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 228.49it/s]
#
#
# Epoch 26: 100%|██████████| 1/1 [00:00<00:00, 11.85it/s, v_num=pdp2, val/loss=0.613]
# Epoch 26: 100%|██████████| 1/1 [00:00<00:00, 11.65it/s, v_num=pdp2, val/loss=0.613]
# Epoch 26:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.613]
# Epoch 27:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.613]
# Epoch 27: 100%|██████████| 1/1 [00:00<00:00, 52.68it/s, v_num=pdp2, val/loss=0.613]
# Epoch 27: 100%|██████████| 1/1 [00:00<00:00, 51.56it/s, v_num=pdp2, val/loss=0.613]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 162.44it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 132.36it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 153.98it/s]
#
#
# Epoch 27: 100%|██████████| 1/1 [00:00<00:00, 11.43it/s, v_num=pdp2, val/loss=0.612]
# Epoch 27: 100%|██████████| 1/1 [00:00<00:00, 11.31it/s, v_num=pdp2, val/loss=0.612]
# Epoch 27:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.612]
# Epoch 28:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.612]
# Epoch 28: 100%|██████████| 1/1 [00:00<00:00, 62.55it/s, v_num=pdp2, val/loss=0.612]
# Epoch 28: 100%|██████████| 1/1 [00:00<00:00, 61.04it/s, v_num=pdp2, val/loss=0.612]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 160.95it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 198.93it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 221.63it/s]
#
#
# Epoch 28: 100%|██████████| 1/1 [00:00<00:00, 11.87it/s, v_num=pdp2, val/loss=0.612]
# Epoch 28: 100%|██████████| 1/1 [00:00<00:00, 11.75it/s, v_num=pdp2, val/loss=0.612]
# Epoch 28:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.612]
# Epoch 29:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.612]
# Epoch 29: 100%|██████████| 1/1 [00:00<00:00, 53.97it/s, v_num=pdp2, val/loss=0.612]
# Epoch 29: 100%|██████████| 1/1 [00:00<00:00, 52.40it/s, v_num=pdp2, val/loss=0.612]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 209.24it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 233.84it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 249.33it/s]
#
#
# Epoch 29: 100%|██████████| 1/1 [00:00<00:00, 11.95it/s, v_num=pdp2, val/loss=0.611]
# Epoch 29: 100%|██████████| 1/1 [00:00<00:00, 11.79it/s, v_num=pdp2, val/loss=0.611]
# Epoch 29:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.611]
# Epoch 30:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.611]
# Epoch 30: 100%|██████████| 1/1 [00:00<00:00, 42.17it/s, v_num=pdp2, val/loss=0.611]
# Epoch 30: 100%|██████████| 1/1 [00:00<00:00, 41.21it/s, v_num=pdp2, val/loss=0.611]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 230.95it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 249.21it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 266.28it/s]
#
#
# Epoch 30: 100%|██████████| 1/1 [00:00<00:00, 12.08it/s, v_num=pdp2, val/loss=0.611]
# Epoch 30: 100%|██████████| 1/1 [00:00<00:00, 11.96it/s, v_num=pdp2, val/loss=0.611]
# Epoch 30:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.611]
# Epoch 31:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.611]
# Epoch 31: 100%|██████████| 1/1 [00:00<00:00, 48.00it/s, v_num=pdp2, val/loss=0.611]
# Epoch 31: 100%|██████████| 1/1 [00:00<00:00, 46.98it/s, v_num=pdp2, val/loss=0.611]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 227.27it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 198.93it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 221.47it/s]
#
#
# Epoch 31: 100%|██████████| 1/1 [00:00<00:00, 11.30it/s, v_num=pdp2, val/loss=0.610]
# Epoch 31: 100%|██████████| 1/1 [00:00<00:00, 11.20it/s, v_num=pdp2, val/loss=0.610]
# Epoch 31:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.610]
# Epoch 32:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.610]
# Epoch 32: 100%|██████████| 1/1 [00:00<00:00, 62.65it/s, v_num=pdp2, val/loss=0.610]
# Epoch 32: 100%|██████████| 1/1 [00:00<00:00, 61.26it/s, v_num=pdp2, val/loss=0.610]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 196.22it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 227.13it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 238.61it/s]
#
#
# Epoch 32: 100%|██████████| 1/1 [00:00<00:00, 12.82it/s, v_num=pdp2, val/loss=0.610]
# Epoch 32: 100%|██████████| 1/1 [00:00<00:00, 12.62it/s, v_num=pdp2, val/loss=0.610]
# Epoch 32:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.610]
# Epoch 33:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.610]
# Epoch 33: 100%|██████████| 1/1 [00:00<00:00, 50.56it/s, v_num=pdp2, val/loss=0.610]
# Epoch 33: 100%|██████████| 1/1 [00:00<00:00, 49.52it/s, v_num=pdp2, val/loss=0.610]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 202.61it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 229.22it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 244.75it/s]
#
#
# Epoch 33: 100%|██████████| 1/1 [00:00<00:00, 12.67it/s, v_num=pdp2, val/loss=0.610]
# Epoch 33: 100%|██████████| 1/1 [00:00<00:00, 12.45it/s, v_num=pdp2, val/loss=0.610]
# Epoch 33:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.610]
# Epoch 34:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.610]
# Epoch 34: 100%|██████████| 1/1 [00:00<00:00, 58.44it/s, v_num=pdp2, val/loss=0.610]
# Epoch 34: 100%|██████████| 1/1 [00:00<00:00, 57.18it/s, v_num=pdp2, val/loss=0.610]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 186.05it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 217.76it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 239.48it/s]
#
#
# Epoch 34: 100%|██████████| 1/1 [00:00<00:00, 12.57it/s, v_num=pdp2, val/loss=0.609]
# Epoch 34: 100%|██████████| 1/1 [00:00<00:00, 12.36it/s, v_num=pdp2, val/loss=0.609]
# Epoch 34:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.609]
# Epoch 35:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.609]
# Epoch 35: 100%|██████████| 1/1 [00:00<00:00, 57.73it/s, v_num=pdp2, val/loss=0.609]
# Epoch 35: 100%|██████████| 1/1 [00:00<00:00, 56.46it/s, v_num=pdp2, val/loss=0.609]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 196.67it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 225.91it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 244.40it/s]
#
#
# Epoch 35: 100%|██████████| 1/1 [00:00<00:00, 13.34it/s, v_num=pdp2, val/loss=0.609]
# Epoch 35: 100%|██████████| 1/1 [00:00<00:00, 13.20it/s, v_num=pdp2, val/loss=0.609]
# Epoch 35:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.609]
# Epoch 36:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.609]
# Epoch 36: 100%|██████████| 1/1 [00:00<00:00, 59.42it/s, v_num=pdp2, val/loss=0.609]
# Epoch 36: 100%|██████████| 1/1 [00:00<00:00, 57.95it/s, v_num=pdp2, val/loss=0.609]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 137.60it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 180.08it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 199.24it/s]
#
#
# Epoch 36: 100%|██████████| 1/1 [00:00<00:00, 12.60it/s, v_num=pdp2, val/loss=0.609]
# Epoch 36: 100%|██████████| 1/1 [00:00<00:00, 12.49it/s, v_num=pdp2, val/loss=0.609]
# Epoch 36:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.609]
# Epoch 37:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.609]
# Epoch 37: 100%|██████████| 1/1 [00:00<00:00, 63.23it/s, v_num=pdp2, val/loss=0.609]
# Epoch 37: 100%|██████████| 1/1 [00:00<00:00, 61.24it/s, v_num=pdp2, val/loss=0.609]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 107.86it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 151.62it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 181.16it/s]
#
#
# Epoch 37: 100%|██████████| 1/1 [00:00<00:00, 12.77it/s, v_num=pdp2, val/loss=0.609]
# Epoch 37: 100%|██████████| 1/1 [00:00<00:00, 12.61it/s, v_num=pdp2, val/loss=0.609]
# Epoch 37:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.609]
# Epoch 38:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.609]
# Epoch 38: 100%|██████████| 1/1 [00:00<00:00, 69.81it/s, v_num=pdp2, val/loss=0.609]
# Epoch 38: 100%|██████████| 1/1 [00:00<00:00, 67.62it/s, v_num=pdp2, val/loss=0.609]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 239.69it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 257.89it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 225.94it/s]
#
#
# Epoch 38: 100%|██████████| 1/1 [00:00<00:00, 12.80it/s, v_num=pdp2, val/loss=0.609]
# Epoch 38: 100%|██████████| 1/1 [00:00<00:00, 12.68it/s, v_num=pdp2, val/loss=0.609]
# Epoch 38:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.609]
# Epoch 39:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.609]
# Epoch 39: 100%|██████████| 1/1 [00:00<00:00, 64.66it/s, v_num=pdp2, val/loss=0.609]
# Epoch 39: 100%|██████████| 1/1 [00:00<00:00, 62.85it/s, v_num=pdp2, val/loss=0.609]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 107.06it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 127.62it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 155.10it/s]
#
#
# Epoch 39: 100%|██████████| 1/1 [00:00<00:00, 12.51it/s, v_num=pdp2, val/loss=0.610]
# Epoch 39: 100%|██████████| 1/1 [00:00<00:00, 12.35it/s, v_num=pdp2, val/loss=0.610]
# Epoch 39:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.610]
# Epoch 40:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.610]
# Epoch 40: 100%|██████████| 1/1 [00:00<00:00, 72.56it/s, v_num=pdp2, val/loss=0.610]
# Epoch 40: 100%|██████████| 1/1 [00:00<00:00, 70.40it/s, v_num=pdp2, val/loss=0.610]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 213.88it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 243.35it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 262.63it/s]
#
#
# Epoch 40: 100%|██████████| 1/1 [00:00<00:00, 14.19it/s, v_num=pdp2, val/loss=0.611]
# Epoch 40: 100%|██████████| 1/1 [00:00<00:00, 13.89it/s, v_num=pdp2, val/loss=0.611]
# Epoch 40:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.611]
# Epoch 41:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.611]
# Epoch 41: 100%|██████████| 1/1 [00:00<00:00, 50.83it/s, v_num=pdp2, val/loss=0.611]
# Epoch 41: 100%|██████████| 1/1 [00:00<00:00, 49.98it/s, v_num=pdp2, val/loss=0.611]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 210.74it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 216.39it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 221.43it/s]
#
#
# Epoch 41: 100%|██████████| 1/1 [00:00<00:00, 12.51it/s, v_num=pdp2, val/loss=0.611]
# Epoch 41: 100%|██████████| 1/1 [00:00<00:00, 12.28it/s, v_num=pdp2, val/loss=0.611]
# Epoch 41:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.611]
# Epoch 42:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.611]
# Epoch 42: 100%|██████████| 1/1 [00:00<00:00, 72.17it/s, v_num=pdp2, val/loss=0.611]
# Epoch 42: 100%|██████████| 1/1 [00:00<00:00, 69.96it/s, v_num=pdp2, val/loss=0.611]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 209.37it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 233.00it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 249.47it/s]
#
#
# Epoch 42: 100%|██████████| 1/1 [00:00<00:00, 13.87it/s, v_num=pdp2, val/loss=0.612]
# Epoch 42: 100%|██████████| 1/1 [00:00<00:00, 13.74it/s, v_num=pdp2, val/loss=0.612]
# Epoch 42:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.612]
# Epoch 43:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.612]
# Epoch 43: 100%|██████████| 1/1 [00:00<00:00, 64.04it/s, v_num=pdp2, val/loss=0.612]
# Epoch 43: 100%|██████████| 1/1 [00:00<00:00, 62.63it/s, v_num=pdp2, val/loss=0.612]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 206.10it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 235.15it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 203.53it/s]
#
#
# Epoch 43: 100%|██████████| 1/1 [00:00<00:00, 12.55it/s, v_num=pdp2, val/loss=0.613]
# Epoch 43: 100%|██████████| 1/1 [00:00<00:00, 12.40it/s, v_num=pdp2, val/loss=0.613]
# Epoch 43:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.613]
# Epoch 44:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.613]
# Epoch 44: 100%|██████████| 1/1 [00:00<00:00, 52.37it/s, v_num=pdp2, val/loss=0.613]
# Epoch 44: 100%|██████████| 1/1 [00:00<00:00, 51.38it/s, v_num=pdp2, val/loss=0.613]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 208.10it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 230.22it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 246.25it/s]
#
#
# Epoch 44: 100%|██████████| 1/1 [00:00<00:00, 11.53it/s, v_num=pdp2, val/loss=0.614]
# Epoch 44: 100%|██████████| 1/1 [00:00<00:00, 11.43it/s, v_num=pdp2, val/loss=0.614]
# Epoch 44:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.614]
# Epoch 45:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.614]
# Epoch 45: 100%|██████████| 1/1 [00:00<00:00, 60.03it/s, v_num=pdp2, val/loss=0.614]
# Epoch 45: 100%|██████████| 1/1 [00:00<00:00, 58.66it/s, v_num=pdp2, val/loss=0.614]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 110.57it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 153.31it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 180.97it/s]
#
#
# Epoch 45: 100%|██████████| 1/1 [00:00<00:00, 12.18it/s, v_num=pdp2, val/loss=0.615]
# Epoch 45: 100%|██████████| 1/1 [00:00<00:00, 11.98it/s, v_num=pdp2, val/loss=0.615]
# Epoch 45:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.615]
# Epoch 46:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.615]
# Epoch 46: 100%|██████████| 1/1 [00:00<00:00, 50.87it/s, v_num=pdp2, val/loss=0.615]
# Epoch 46: 100%|██████████| 1/1 [00:00<00:00, 49.63it/s, v_num=pdp2, val/loss=0.615]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 209.89it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 230.23it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 238.39it/s]
#
#
# Epoch 46: 100%|██████████| 1/1 [00:00<00:00, 12.89it/s, v_num=pdp2, val/loss=0.617]
# Epoch 46: 100%|██████████| 1/1 [00:00<00:00, 12.73it/s, v_num=pdp2, val/loss=0.617]
# Epoch 46:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.617]
# ...
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 201.79it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 221.16it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 231.18it/s]
#
#
# Epoch 86: 100%|██████████| 1/1 [00:00<00:00, 12.28it/s, v_num=pdp2, val/loss=0.654]
# Epoch 86: 100%|██████████| 1/1 [00:00<00:00, 12.15it/s, v_num=pdp2, val/loss=0.654]
# Epoch 86:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.654]
# Epoch 87:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.654]
# Epoch 87: 100%|██████████| 1/1 [00:00<00:00, 57.76it/s, v_num=pdp2, val/loss=0.654]
# Epoch 87: 100%|██████████| 1/1 [00:00<00:00, 56.27it/s, v_num=pdp2, val/loss=0.654]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 208.72it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 222.17it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 234.25it/s]
#
#
# Epoch 87: 100%|██████████| 1/1 [00:00<00:00, 11.52it/s, v_num=pdp2, val/loss=0.656]
# Epoch 87: 100%|██████████| 1/1 [00:00<00:00, 11.41it/s, v_num=pdp2, val/loss=0.656]
# Epoch 87:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.656]
# Epoch 88:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.656]
# Epoch 88: 100%|██████████| 1/1 [00:00<00:00, 59.45it/s, v_num=pdp2, val/loss=0.656]
# Epoch 88: 100%|██████████| 1/1 [00:00<00:00, 58.15it/s, v_num=pdp2, val/loss=0.656]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 228.77it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 246.23it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 252.99it/s]
#
#
# Epoch 88: 100%|██████████| 1/1 [00:00<00:00, 12.42it/s, v_num=pdp2, val/loss=0.657]
# Epoch 88: 100%|██████████| 1/1 [00:00<00:00, 12.27it/s, v_num=pdp2, val/loss=0.657]
# Epoch 88:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.657]
# Epoch 89:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.657]
# Epoch 89: 100%|██████████| 1/1 [00:00<00:00, 59.22it/s, v_num=pdp2, val/loss=0.657]
# Epoch 89: 100%|██████████| 1/1 [00:00<00:00, 57.77it/s, v_num=pdp2, val/loss=0.657]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 202.05it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 220.98it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 232.30it/s]
#
#
# Epoch 89: 100%|██████████| 1/1 [00:00<00:00, 12.84it/s, v_num=pdp2, val/loss=0.658]
# Epoch 89: 100%|██████████| 1/1 [00:00<00:00, 12.71it/s, v_num=pdp2, val/loss=0.658]
# Epoch 89:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.658]
# Epoch 90:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.658]
# Epoch 90: 100%|██████████| 1/1 [00:00<00:00, 67.69it/s, v_num=pdp2, val/loss=0.658]
# Epoch 90: 100%|██████████| 1/1 [00:00<00:00, 65.55it/s, v_num=pdp2, val/loss=0.658]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 138.16it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 179.47it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 195.97it/s]
#
#
# Epoch 90: 100%|██████████| 1/1 [00:00<00:00, 12.35it/s, v_num=pdp2, val/loss=0.660]
# Epoch 90: 100%|██████████| 1/1 [00:00<00:00, 12.15it/s, v_num=pdp2, val/loss=0.660]
# Epoch 90:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.660]
# Epoch 91:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.660]
# Epoch 91: 100%|██████████| 1/1 [00:00<00:00, 62.40it/s, v_num=pdp2, val/loss=0.660]
# Epoch 91: 100%|██████████| 1/1 [00:00<00:00, 60.40it/s, v_num=pdp2, val/loss=0.660]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 219.49it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 223.21it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 219.74it/s]
#
#
# Epoch 91: 100%|██████████| 1/1 [00:00<00:00, 12.19it/s, v_num=pdp2, val/loss=0.661]
# Epoch 91: 100%|██████████| 1/1 [00:00<00:00, 12.05it/s, v_num=pdp2, val/loss=0.661]
# Epoch 91:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.661]
# Epoch 92:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.661]
# Epoch 92: 100%|██████████| 1/1 [00:00<00:00, 58.32it/s, v_num=pdp2, val/loss=0.661]
# Epoch 92: 100%|██████████| 1/1 [00:00<00:00, 57.00it/s, v_num=pdp2, val/loss=0.661]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 227.27it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 250.32it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 268.19it/s]
#
#
# Epoch 92: 100%|██████████| 1/1 [00:00<00:00, 13.26it/s, v_num=pdp2, val/loss=0.664]
# Epoch 92: 100%|██████████| 1/1 [00:00<00:00, 13.02it/s, v_num=pdp2, val/loss=0.664]
# Epoch 92:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.664]
# Epoch 93:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.664]
# Epoch 93: 100%|██████████| 1/1 [00:00<00:00, 57.39it/s, v_num=pdp2, val/loss=0.664]
# Epoch 93: 100%|██████████| 1/1 [00:00<00:00, 56.23it/s, v_num=pdp2, val/loss=0.664]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 103.74it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 123.00it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 134.40it/s]
#
#
# Epoch 93: 100%|██████████| 1/1 [00:00<00:00, 10.86it/s, v_num=pdp2, val/loss=0.667]
# Epoch 93: 100%|██████████| 1/1 [00:00<00:00, 10.76it/s, v_num=pdp2, val/loss=0.667]
# Epoch 93:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.667]
# Epoch 94:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.667]
# Epoch 94: 100%|██████████| 1/1 [00:00<00:00, 45.48it/s, v_num=pdp2, val/loss=0.667]
# Epoch 94: 100%|██████████| 1/1 [00:00<00:00, 44.50it/s, v_num=pdp2, val/loss=0.667]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 148.33it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 182.43it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 205.62it/s]
#
#
# Epoch 94: 100%|██████████| 1/1 [00:00<00:00, 12.20it/s, v_num=pdp2, val/loss=0.669]
# Epoch 94: 100%|██████████| 1/1 [00:00<00:00, 12.07it/s, v_num=pdp2, val/loss=0.669]
# Epoch 94:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.669]
# Epoch 95:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.669]
# Epoch 95: 100%|██████████| 1/1 [00:00<00:00, 50.50it/s, v_num=pdp2, val/loss=0.669]
# Epoch 95: 100%|██████████| 1/1 [00:00<00:00, 49.35it/s, v_num=pdp2, val/loss=0.669]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 249.66it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 261.75it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 273.11it/s]
#
#
# Epoch 95: 100%|██████████| 1/1 [00:00<00:00, 12.93it/s, v_num=pdp2, val/loss=0.673]
# Epoch 95: 100%|██████████| 1/1 [00:00<00:00, 12.79it/s, v_num=pdp2, val/loss=0.673]
# Epoch 95:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.673]
# Epoch 96:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.673]
# Epoch 96: 100%|██████████| 1/1 [00:00<00:00, 55.95it/s, v_num=pdp2, val/loss=0.673]
# Epoch 96: 100%|██████████| 1/1 [00:00<00:00, 54.80it/s, v_num=pdp2, val/loss=0.673]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 154.06it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 192.05it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 212.80it/s]
#
#
# Epoch 96: 100%|██████████| 1/1 [00:00<00:00, 11.53it/s, v_num=pdp2, val/loss=0.678]
# Epoch 96: 100%|██████████| 1/1 [00:00<00:00, 11.43it/s, v_num=pdp2, val/loss=0.678]
# Epoch 96:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.678]
# Epoch 97:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.678]
# Epoch 97: 100%|██████████| 1/1 [00:00<00:00, 47.25it/s, v_num=pdp2, val/loss=0.678]
# Epoch 97: 100%|██████████| 1/1 [00:00<00:00, 45.91it/s, v_num=pdp2, val/loss=0.678]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 231.58it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 248.86it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 260.39it/s]
#
#
# Epoch 97: 100%|██████████| 1/1 [00:00<00:00, 12.28it/s, v_num=pdp2, val/loss=0.678]
# Epoch 97: 100%|██████████| 1/1 [00:00<00:00, 12.04it/s, v_num=pdp2, val/loss=0.678]
# Epoch 97:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.678]
# Epoch 98:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.678]
# Epoch 98: 100%|██████████| 1/1 [00:00<00:00, 49.30it/s, v_num=pdp2, val/loss=0.678]
# Epoch 98: 100%|██████████| 1/1 [00:00<00:00, 48.20it/s, v_num=pdp2, val/loss=0.678]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 225.09it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 244.94it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 257.34it/s]
#
#
# Epoch 98: 100%|██████████| 1/1 [00:00<00:00, 11.86it/s, v_num=pdp2, val/loss=0.676]
# Epoch 98: 100%|██████████| 1/1 [00:00<00:00, 11.66it/s, v_num=pdp2, val/loss=0.676]
# Epoch 98:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.676]
# Epoch 99:   0%|          | 0/1 [00:00<?, ?it/s, v_num=pdp2, val/loss=0.676]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 51.64it/s, v_num=pdp2, val/loss=0.676]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 50.38it/s, v_num=pdp2, val/loss=0.676]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 212.32it/s]
#
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 234.40it/s]
#
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 250.17it/s]
#
#
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 12.74it/s, v_num=pdp2, val/loss=0.677]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 12.61it/s, v_num=pdp2, val/loss=0.677]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00,  7.79it/s, v_num=pdp2, val/loss=0.677]
# Using supervised mode.
# Moleculenet sider dataset loaded with 42 labeled, 142 validation, and 287 test samples.
# Batch sizes: labeled=256
#
# Testing: |          | 0/? [00:00<?, ?it/s]
# Testing:   0%|          | 0/5 [00:00<?, ?it/s]
# Testing DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Testing DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 129.69it/s]
# Testing DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 170.52it/s]
# Testing DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 182.61it/s]
# Testing DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 193.89it/s]
# Testing DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 205.60it/s]
# Testing DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 77.52it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test/acc          │     0.605368435382843     │
# │          test/ap          │    0.5872400917265653     │
# │          test/f1          │    0.5104408264160156     │
# │         test/loss         │    0.6992954611778259     │
# │        test/pr_auc        │    0.5833255163402263     │
# │       test/roc_auc        │    0.4852457874543048     │
# └───────────────────────────┴───────────────────────────┘
# Loading best model from: /home/prg/GitHub/semi-supervised-gnn-drug-discovery/workspace/logs/SIDER_Experiments/jedcpdp2/checkpoints/best.ckpt
# [2025-12-05 20:06:13,416][src.lightning_modules.baseline][INFO] - Loaded weights from /home/prg/GitHub/semi-supervised-gnn-drug-discovery/workspace/logs/SIDER_Experiments/jedcpdp2/checkpoints/best.ckpt
# Using supervised mode.
# Moleculenet sider dataset loaded with 42 labeled, 142 validation, and 287 test samples.
# Batch sizes: labeled=256
#
# Testing: |          | 0/? [00:00<?, ?it/s]
# Testing:   0%|          | 0/5 [00:00<?, ?it/s]
# Testing DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Testing DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 130.34it/s]
# Testing DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 160.31it/s]
# Testing DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 176.08it/s]
# Testing DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 182.30it/s]
# Testing DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 186.25it/s]
# Testing DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 72.83it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test/acc          │    0.5152922868728638     │
# │          test/ap          │    0.5893429719217559     │
# │          test/f1          │     0.400779128074646     │
# │         test/loss         │    0.6605695486068726     │
# │        test/pr_auc        │    0.5852904819577671     │
# │       test/roc_auc        │    0.4951242404392095     │
# └───────────────────────────┴───────────────────────────┘
# wandb:
# wandb: 🚀 View run moleculenet_GINEv2_2025-12-05_20-05-57 at:
# wandb: Find logs at: workspace/logs/wandb/run-20251205_200558-jedcpdp2/logs
#
# Experiment completed successfully.

# %% [markdown]
# ### Mean Teacher

# %%
# --- 3b. Mean Teacher (SIDER) ---
    # Common splits for semi-supervised learning [Unlabeled, Labeled, Val, Test]

# - Experiment 1: [0.35,0.35,0.1,0.2]"
# - Experiment 2: [0.56,0.14,0.1,0.2]"
# - Experiment 3: [0.63,0.07,0.1,0.2]"
# - Experiment 4: [0.67,0.03,0.1,0.2]"


SSL_SPLITS = "[0.67,0.03,0.1,0.2]"

sider_mt_overrides = [
    "dataset=moleculenet",
    "dataset.init.name=SIDER", # SIDER, TOX21 or PCBA
    f"dataset.init.splits={SSL_SPLITS}",
    "dataset.init.batch_size_train=32",
    "dataset.init.mu=1",
    "trainer.init.max_epochs=100",  # Reduced for demo purposes
    "logger.wandb.project=SIDER_Experiments"
]

run_experiment(MEAN_TEACHER_TRAINER, sider_mt_overrides)
